# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combine_df = pd.merge(study_results, mouse_metadata, how='outer', on="Mouse ID")

# XXXcombine_df = pd.concat([ study_results, mouse_metadata], ignore_index=True, sort=False)
# Display the data table for preview

combine_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %% [markdown]
# # This is GW Backup
# #### ****Combine the data into a single dataset****
# ### combine_df = pd.concat([study_results, mouse_metadata]).drop_duplicates()
# ### combine_frames = [study_results, mouse_metadata]
# ### combine_df = pd.concat
# ### XXXXXcombined_pym_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")   #, how="right", on=["Mouse ID", "Mouse ID"])
# ### combine_df.dtypes
# ### XXXXXMouseAndTime_df = combined_pym_df.set_index(["Mouse ID", "Timepoint"])["Timepoint"]
# ### MouseAndTime_df = per_mice_ID & combined_pym_df(["Timepoint"])
# ### clean_mouse_df.describe()
# ### plt.xticks(rotation="vertical")
# ### plt.show()

# %% [markdown]
# ###This is My Own idea (delete soon)
# Sample:  fires_cleaned_df = fires_reduced.fillna(0)
# clean_mouseid = combine_df.groupby("Mouse ID")
# clean_mouseid.first()

# %% [markdown]
# # just for test
# test = combine_df["Mouse ID"].unique()
# test

# %% [markdown]
# # Syntax of drop_duplicates
# DataFrame.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

# %%
# Checking the number of mice.
number_mice = combine_df["Mouse ID"].drop_duplicates()
number_mice

# number_mice = len(combine_df.index)
# number_mice = len(combine_df["Mouse ID"].index)
# print(number_mice.duplicated["Mouse ID"])
# print(~combine_df.duplicated())
# Out:
# 0       b128
# 10      f932
# 11      g107
# 19      a457
# 22      c819
#         ...
# 1848    t565
# 1858    i557
# 1868    m957
# 1878    f966
# 1883    m601
# Name: Mouse ID, Length: 249, dtype: object

# %% [markdown]
# # ? need help

# %%
# Backup
# per_mice_ID = mice_count.groupby(["Mouse ID"]).count()
# XXXXXMouseAndTime = mice_count.set_index(["Mouse ID"])["Timepoint"]
# MouseAndTime = pd.array([mice_count],dtype=str)
# XXXdup_mice_time = pd.array(["Timepoint"],dtype=object)
### 04/2/02-Stu_GoodMovies-Loc// good_movies_df = movie_file_df.loc[movie_file_df["IMDB"] > 7, ["FILM", "IMDB", "IMDB_user_vote_count"]]
# dup_mouseID_time = combine_df.loc[combine_df.duplicated['Mouse ID', 'Timepoint'].unique()


# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
dup_mouseID_time = combine_df.loc[combine_df.duplicated(subset=['Mouse ID', 'Timepoint']),'Mouse ID'].unique()
dup_mouseID_time
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouseID_time_df = combine_df.loc[combine_df["Mouse ID"] == "g989", :]
dup_mouseID_time_df

# MouseAndDrug = combine_df.set_index(["Mouse ID"])["Drug Regimen"]
# MouseAndSex = combine_df.set_index(["Mouse ID"])["Sex"]
# MouseAndAge = combine_df.set_index(["Mouse ID"])["Age_months"]
# MouseAndWeight = combine_df.set_index(["Mouse ID"])["Weight (g)"]
# MouseAndTumor = combine_df.set_index(["Mouse ID"])["Tumor Volume (mm3)"]
# MouseAndMeta = combine_df.set_index(["Mouse ID"])["Metastatic Sites"]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# ...

# %%
combine_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
#Idea 1.1
new_mouseID_df = pd.DataFrame(
    {
         "Mouse ID": number_mice,
    }
)
# clean_mouse_df = clean_mouse_df["Mouse ID"].drop_duplicates()
new_mouseID_df.head()
# Out:
#    Mouse ID
# 0      b128
# 10     f932
# 11     g107
# 19     a457
# 22     c819

# %%
#idea 1.2
# removeid_combine_df = combine_df.loc[:, ["Timepoint", "Tumor Volume (mm3)", "Metastatic Sites", "Drug Regimen", "Sex	Age_months", "Weight (g)"]]                                 
removeid_combine_df = combine_df.loc[:, ["Timepoint", "Tumor Volume (mm3)", "Metastatic Sites",
                                    "Drug Regimen", "Sex", "Age_months", "Weight (g)"]]
removeid_combine_df

# Timepoint	Tumor Volume (mm3)	Metastatic Sites	Drug Regimen	Sex	Age_months	Weight (g)
# Out:
#       Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen     Sex  \
# 0             0           45.000000                 0    Capomulin  Female
# 1             5           45.651331                 0    Capomulin  Female
# 2            10           43.270852                 0    Capomulin  Female
# 3            15           43.784893                 0    Capomulin  Female
# 4            20           42.731552                 0    Capomulin  Female
# ...         ...                 ...               ...          ...     ...
# 1888         25           33.118756                 1    Capomulin    Male
# 1889         30           31.758275                 1    Capomulin    Male
# 1890         35           30.834357                 1    Capomulin    Male
# 1891         40           31.378045                 1    Capomulin    Male
# 1892         45           28.430964                 1    Capomulin    Male
#
#       Age_months  Weight (g)
# 0              9          22
# ...

# %% [markdown]
# # ???need help - cannot make same as file supply
#
# Set 1 effect below "Quartiles, Outliers and Boxplots" / Calculate the final tumor volume of each mouse across four of the treatment regimens: / ""just only show tittle on 1st column and not mean, medium
#
# Set 2 is good but why?

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# data = [new_mouseID_df, removeid_combine_df]
#Set 1
# clean_mouse_df = new_mouseID_df.append([new_mouseID_df, removeid_combine_df])
# clean_mouse_df

# Set 2
clean_mouse_df = combine_df[combine_df['Mouse ID'].isin(dup_mouseID_time)==False]
clean_mouse_df


# combine_df["Mouse ID"].drop_duplicates()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice_num = clean_mouse_df["Mouse ID"].nunique()
clean_mice_num
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
drug_regimen_mean = clean_mouse_df['Tumor Volume (mm3)'].groupby(clean_mouse_df['Drug Regimen']).mean()
drug_regimen_median = clean_mouse_df['Tumor Volume (mm3)'].groupby(clean_mouse_df['Drug Regimen']).median()
drug_regimen_var = clean_mouse_df['Tumor Volume (mm3)'].groupby(clean_mouse_df['Drug Regimen']).var()
drug_regimen_std_deciation = clean_mouse_df['Tumor Volume (mm3)'].groupby(clean_mouse_df['Drug Regimen']).std()
drug_regimen_sem = clean_mouse_df['Tumor Volume (mm3)'].groupby(clean_mouse_df['Drug Regimen']).sem()


# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
mean_med_var_stand_sem_summary_df = pd.DataFrame({"Mean Tumor Volume":drug_regimen_mean, 
                            "Median Tumor Volume":drug_regimen_median, 
                           "Tumor Volume Variance":drug_regimen_var, 
                           "Tumor Volume Std. Dev.":drug_regimen_std_deciation, 
                           "Tumor Volume Std. Err.":drug_regimen_sem})


mean_med_var_stand_sem_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
summary_Statistics_aggregation =  clean_mouse_df.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].aggregate(['mean', 'median', 'var', 'std', 'sem'])
summary_Statistics_aggregation
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %% [markdown]
# # ??? Need help all chart is not showing after reopen jupyther notebook

# %%
# Idea to clean "Drug Regimen" on data frame and counts. Because my chart is not match the Assignment supplied answer.
drug_count = clean_mouse_df["Drug Regimen"].value_counts()
drug_count
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     148
# Name: Drug Regimen, dtype: int64

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
plot_pandas = drug_count.plot.bar(color='Red') 
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.title("Mice number of testing in Drug Regimen")
# plt.savefig("../Images/MiceNumberOfTestingInDrugRegimen.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Mice number of testing in Drug Regimen')

# %%
timepoints_count = clean_mouse_df["Timepoint"].value_counts()
timepoints_count
# Out:
# 0     248
# 5     236
# 10    221
# 15    205
# 20    193
# 25    182
# 30    170
# 35    153
# 40    142
# 45    130
# Name: Timepoint, dtype: int64

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

x_axis = timepoints_count.index.values
y_axis = timepoints_count.values

plot_pandas = timepoints_count.plot.bar(color='Green') 
plt.title("Total number Tested in timepoints")
plt.xlabel("timepoints")
plt.ylabel("Mice number")
# plt.savefig("../Images/TotalNumberTestedInTimepoints.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Mice number')

# %%
sex_data = clean_mouse_df["Sex"].value_counts()
sex_data
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex_data = clean_mouse_df["Sex"].value_counts()
plt.title("Female and Male Mice distribution")
sex_data.plot.pie(autopct= "%1.3f%%")
# plt.savefig("../Images/FemaleAndMaleMiceDistribution.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:title={'center':'Female and Male Mice distribution'}, ylabel='Sex'>

# %% [markdown]
# # ???????*****I'm not sure is this pie chat correct********

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ['Female', 'Male']
sizes = [49.043, 50.957]
plt.pie(sex_data.values, labels=labels, autopct="%1.1f%%")
plt.title('Male vs Female Mouse number Percentage')
plt.ylabel('Sex')
# plt.savefig("../Images/MaleVsFemaleMouseNumberPercentage.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %% [markdown]
# ####For review
# clean_mouse_df

# %%
Capomulin_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Capomulin",:]
Capomulin_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
####For review
clean_mouse_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %% [markdown]
# # Test only
# Ceftamin_df_greatest_timelist = Ceftamin_df.groupby('Mouse ID').max()['Timepoint']
# Ceftamin_df_only_MouseIdTime_df = pd.DataFrame(Ceftamin_df_greatest_timelist)
# Ceftamin_df_greatest_df = pd.merge(Ceftamin_df_only_MouseIdTime_df, clean_mouse_df, on=("Mouse ID","Timepoint"),how="left")
# Ceftamin_df_greatest_df
#
# ####BU for Merge this group
# # Merge_group = ["Capomulin_greatest_df", "Ramicane_greatest_df", "Infubinol_greatest_df", "Ceftamin_df_greatest_df"]
# # Cap_Ram_Inf_Ceft_df = pd.merge(Capomulin_greatest_df, Ramicane_greatest_df, Infubinol_greatest_df, Ceftamin_df_greatest_df, on=("Mouse ID", "Timepoint","Tumor Volume (mm3)","Metastatic Sites","Drug Regimen","Sex","Age_months","Weight (g)"), how="left")

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse.
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint.

MT_df = clean_mouse_df[["Mouse ID","Timepoint"]].groupby("Mouse ID").max().reset_index()
merge_df = MT_df.merge(clean_mouse_df, how="left", on=["Mouse ID", "Timepoint"])
merge_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %% [markdown]
# # ????? Not sure is this correct

# %% [markdown]
# # Below the script is before BCS teach
# # Calculate the final tumor volume of each mouse across four of the treatment regimens:

# %% [markdown]
# #********Backup**********
# # Calculate the final tumor volume of each mouse across four of the treatment regimens:
# # Capomulin, Ramicane, Infubinol, and Ceftamin
# Capomulin_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Capomulin",:]
# Ramicane_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Ramicane", :]
# Infubinol_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Infubinol", :]
# Ceftamin_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Ceftamin", :]
#
# # Start by getting the last (greatest) timepoint for each mouse
# Capomulin_greatest_timelist = Capomulin_df.groupby('Mouse ID').max()['Timepoint']
# Capomulin_only_MouseIdTime_df = pd.DataFrame(Capomulin_greatest_timelist)
# Capomulin_greatest_df = pd.merge(Capomulin_only_MouseIdTime_df, clean_mouse_df, on=("Mouse ID","Timepoint"),how="left")
# # Capomulin_greatest_df
#
# Ramicane_greatest_timelist = Ramicane_df.groupby('Mouse ID').max()['Timepoint']
# Ramicane_only_MouseIdTime_df = pd.DataFrame(Ramicane_greatest_timelist)
# Ramicane_greatest_df = pd.merge(Ramicane_only_MouseIdTime_df, clean_mouse_df, on=("Mouse ID","Timepoint"),how="left")
# # Ramicane_greatest_df
#
# Infubinol_greatest_timelist = Infubinol_df.groupby('Mouse ID').max()['Timepoint']
# Infubinol_only_MouseIdTime_df = pd.DataFrame(Infubinol_greatest_timelist)
# Infubinol_greatest_df = pd.merge(Infubinol_only_MouseIdTime_df, clean_mouse_df, on=("Mouse ID","Timepoint"),how="left")
# # Infubinol_greatest_df
#
# Ceftamin_df_greatest_timelist = Ceftamin_df.groupby('Mouse ID').max()['Timepoint']
# Ceftamin_df_only_MouseIdTime_df = pd.DataFrame(Ceftamin_df_greatest_timelist)
# Ceftamin_df_greatest_df = pd.merge(Ceftamin_df_only_MouseIdTime_df, clean_mouse_df, on=("Mouse ID","Timepoint"),how="left")
# Ceftamin_df_greatest_df
#
# # Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
#
# # Cap_Ram_Inf_Ceft_df = pd.merge(Capomulin_greatest_df, Ramicane_greatest_df, Infubinol_greatest_df, Ceftamin_df_greatest_df, on=("Mouse ID","Timepoint"),how="left")
# # Cap_Ram_Inf_Ceft_df

# %% [markdown]
# # ????? Not sure want a list or not

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = 0
treatment regimens_list = [Ramicane_greatest_df", "Infubinol_greatest_df", "Ceftamin_df_greatest_df"]
for drug in drug_list:

# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
Capomulin_df = clean_mouse_df.loc[clean_mouse_df["Drug Regimen"] == "Capomulin",:]
Capomulin_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
# *****problem, I don't know why is only 1509 will show the line graph*****???????????????????????

lineplot_df = Capomulin_df.loc[Capomulin_df["Mouse ID"] == "l509",:]
lineplot_df.head()
x = lineplot_df["Timepoint"]
y = lineplot_df["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.title('Mouse treated with Capomulin')
plt.plot(x, y,linewidth=1, markersize=8,marker="o",color="Orange")
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

fig1, ax1 = plt.subplots()
avgcapo_vol =Capomulin_df.groupby(['Mouse ID']).mean()

marker_size=15
plt.scatter(avgcapo_vol['Weight (g)'],avgcapo_vol['Tumor Volume (mm3)'], color="red")
plt.title('Capomulin regimen - Average tumor volume vs. mouse weight')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Average Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
